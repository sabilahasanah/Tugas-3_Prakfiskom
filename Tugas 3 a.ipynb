# %%
SABILA HASANAH(1217030034)

# %%
import pandas as pd

last_names = ['Cannor', 'Cannor', 'Reese']
first_names = ['Sarah', 'John', 'Kyle']
df = pd.DataFrame({
    'first_name' : first_names,
    'last_name' : last_names,
})

url = "https://github.com/luminati-io/Instagram-dataset-samples/raw/main/Instagram%20Profiles%20-%20Github%20Hashtag.xlsx"
database = pd.read_excel(url)
'''pd.read_csv('data.csv')'''
print(database.columns)
print(database.describe())
print(database.head())
print(database.tail())
# Out:
# Index(['account', 'biography', 'business_address_json',
#        'business_category_name', 'business_email', 'external_url', 'fbid',
#        'followers', 'following', 'highlights', 'id', 'is_business_account',
#        'is_professional_account', 'is_verified', 'posts', 'posts_count',
#        'profile_image_link', 'profile_name', 'timestamp', 'highlights_count',
#        'country_code', 'region', 'avg_engagement', 'post_hashtags',
#        'maybe_country_codes', 'bio_hashtags', 'avatar_cached', 'category_enum',
#        'category_name', 'changelog', 'full_name', 'is_private'],
#       dtype='object')
#                fbid      followers    following            id   posts_count  \
# count  2.180000e+03    2180.000000  2180.000000  2.180000e+03   2180.000000
# mean   1.784142e+16    3742.219725   833.504128  1.578932e+10    174.810092
# std    1.609949e+10   20916.841627  1262.555265  1.610490e+10    460.206757
# min    1.784140e+16     101.000000     0.000000  3.188200e+05      0.000000
# 25%    1.784140e+16     239.000000   163.000000  2.277471e+09     25.000000
# 50%    1.784141e+16     519.000000   402.500000  7.776540e+09     63.000000
# 75%    1.784143e+16    1207.000000   889.500000  3.219110e+10    160.000000
# max    1.784145e+16  548827.000000  7502.000000  4.885600e+10  11031.000000
#
#        highlights_count  avg_engagement
# count       2180.000000     2119.000000
# mean           4.218807        0.107939
# std            9.096056        0.230528
# min            0.000000        0.000200
# 25%            0.000000        0.031450
# 50%            2.000000        0.070000
# 75%            6.000000        0.134850
# max          266.000000        8.826900
#              account                                          biography  \
# 0        yazilim.exe  ◾️𝗖𝝝𝗗𝗜𝗡𝗚  ◾️𝗪𝗘𝗕 𝗗𝗘𝗩𝗘𝗟𝝝𝗣𝗘𝗥\n◾️𝗣𝗥𝝝𝗚𝗥𝝠𝗠𝗠𝗘𝗥 ◾️𝗦𝝝𝗖𝗜...
# 1  yazilimci.genclik  👩‍💻  Yazılımcı Gençlerin Buluşma Noktası 👨‍💻...
# 2    yazilim.academy  🏢 Istanbul Technical University\n📍 Sıfırdan C ...
# 3       yahya.kassid  #kdB.\nHi. and welcome I'm a #WebDesigner & #O...
# 4           xnetking  🔥 | Developer's Planet ⚡\n📛 | Learn Coding ess...
#
#                                business_address_json  \
# 0  {"city_name":null,"city_id":null,"latitude":nu...
# 1  {"city_name":null,"city_id":null,"latitude":nu...
# 2  {"city_name":null,"city_id":null,"latitude":nu...
# 3                                                NaN
# 4                                                NaN
#
#                         business_category_name                business_email  \
# 0                       Creators & Celebrities                           NaN
# 1        Non-Profits & Religious Organizations  info@yazilimcigenclik.com.tr
# 2  Personal Goods & General Merchandise Stores                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
#
#                                         external_url               fbid  \
# 0  https://www.youtube.com/watch?v=Otnurz26st0&t=...  17841433403389642
# 1          https://yazilimcigenclik.com.tr/telegram/  17841405759210094
# 2                                                NaN  17841438889421479
# 3                            http://yahyakassid.com/  17841400997616912
# 4                           https://www.xnetking.in/  17841442359060543
#
#    followers  following                                         highlights  \
# 0        880        354  [{"id":"17880714053008666","title":"Sound&#x1F...
# 1      24036        103  [{"id":"18121606399097057","title":"Sosyal Med...
# 2       2827       6695  [{"id":"17974324465320629","title":"Yaz&#x131;...
# 3       1345        169                                                 []
# 4        208         73  [{"id":"17917345264765375","title":"Resources"...
#
#    ...  avg_engagement                                      post_hashtags  \
# 0  ...          0.0482  ["code","yazilim","programmation","motivation"...
# 1  ...          0.0081  ["yazilimcigenclik","programlama","programlama...
# 2  ...          0.0426  ["software","cprogramming","cprogramlama","yaz...
# 3  ...          0.0192  ["websitedesigner","designweb","web_design","w...
# 4  ...          0.0985  ["coding","developer","software","webdeveloper...
#
#   maybe_country_codes                                bio_hashtags  \
# 0                 NaN                                         NaN
# 1                 NaN                                         NaN
# 2                 NaN                                         NaN
# 3              ["RU"]  ["kdb","webdesigner","onlinestorebuilder"]
# 4                 NaN                                         NaN
#
#              avatar_cached  category_enum category_name  \
# 0                      NaN            NaN           NaN
# 1                      NaN            NaN           NaN
# 2                      NaN            NaN           NaN
# 3  avatar_yahya.kassid.jpg            NaN   Предприемач
# 4                      NaN            NaN           NaN
#
#                                            changelog  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{"followers":1377,"following":172,"avg_engage...
# 4                                                NaN
#
#                      full_name  is_private
# 0                          NaN          no
# 1                          NaN          no
# 2                          NaN          no
# 3  Yahya kassid | web designer          no
# 4                          NaN          no
#
# [5 rows x 32 columns]
#                  account                                          biography  \
# 2175     i_am_ajay_yadav  💡Programmer / #github / writer \n Laparwaah......
# 2176           isajergys  Software Developement Engineer\n      Fullstac...
# 2177  abhisekmajumder331                     #xdadevelopers #github #heroku
# 2178             markxoe  m/17\n.\nBillo Software Entwickler #js #react ...
# 2179   lokendra.rajput.1  #20 OCT 🎂🎉\n#softwaredeveloper 💻🤗\n#sanchi 🏣\n...
#
#      business_address_json business_category_name business_email  \
# 2175                   NaN                    NaN            NaN
# 2176                   NaN                    NaN            NaN
# 2177                   NaN                    NaN            NaN
# 2178                   NaN                    NaN            NaN
# 2179                   NaN                    NaN            NaN
#
#                     external_url               fbid  followers  following  \
# 2175                         NaN  17841404238986616        987        532
# 2176                         NaN  17841404283177971        238        325
# 2177                         NaN  17841404383182890        144        189
# 2178  https://github.com/markxoe  17841406016893190        250        974
# 2179                         NaN  17841406215816607        486       2598
#
#                                              highlights  ...  avg_engagement  \
# 2175  [{"id":"17859333128554014","title":"Ganna","im...  ...          0.0336
# 2176                                                 []  ...             NaN
# 2177                                                 []  ...          0.1197
# 2178                                                 []  ...             NaN
# 2179  [{"id":"17867057143581797","title":"Winter Sea...  ...          0.1881
#
#                       post_hashtags maybe_country_codes  \
# 2175                            NaN                 NaN
# 2176                            NaN                 NaN
# 2177                ["back","pubg"]                 NaN
# 2178                            NaN                 NaN
# 2179  ["cafe","angular7","laravel"]                 NaN
#
#                                            bio_hashtags  \
# 2175                                         ["github"]
# 2176  ["java","spring","vuejs","angular","react","gc...
# 2177                ["xdadevelopers","github","heroku"]
# 2178  ["js","react","capacitor","esp8266","github","...
# 2179  ["20","softwaredeveloper","sanchi","bahuthard"...
#
#                       avatar_cached  category_enum category_name changelog  \
# 2175     avatar_i_am_ajay_yadav.jpg            NaN           NaN       NaN
# 2176           avatar_isajergys.jpg            NaN           NaN       NaN
# 2177  avatar_abhisekmajumder331.jpg            NaN         Gamer       NaN
# 2178             avatar_markxoe.jpg            NaN           NaN       NaN
# 2179   avatar_lokendra.rajput.1.jpg            NaN           NaN       NaN
#
#                full_name  is_private
# 2175          Ajay Yadav          no
# 2176          Ergys ISAJ         yes
# 2177            Abhishek          no
# 2178  Mark Oude Elberink         yes
# 2179     Lokendra Rajput          no
#
# [5 rows x 32 columns]
